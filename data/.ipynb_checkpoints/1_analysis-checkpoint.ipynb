# %% [markdown]
# # Balloon Analog Risk Task behavioral data analysis
# Written by Nill

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. demographic data
#
# this is <b>Nill's </b> data

# %%
file_path = '1_nill/demographic_data_10_09_2024_18_55_45.csv'

demographic = pd.read_csv(file_path)
demographic
# Out:
#    Gender     Age                Ethnicity    Race
# 0  Female   25-34   Not Hispanic or Latino   White

# %% [markdown]
# ## 2. task data

# %%
file_path = '1_nill/task_data_10_09_2024_19_18_13.csv'
task = pd.read_csv(file_path)
task
# Out:
#     balloonType outcome  reactionTime (ms)  inflationTime (ms)  reward
# 0          gray  popped             1446.9              2901.1       0
# 1           red  banked              298.8              1266.6      12
# 2          gray  popped              302.4              2900.3      12
# 3        yellow  banked              466.8              1024.3      22
# 4           red  banked              231.8              1240.3      34
# ..          ...     ...                ...                 ...     ...
# 245         red  popped             1234.8              1501.8    3843
# 246      orange  banked              203.0              1634.0    3859
# 247        gray  popped              483.6              2901.9    3859
# 248         red  banked              339.9              1450.9    3873
# 249      yellow  banked              445.0              2231.4    3895
#
# [250 rows x 5 columns]

# %% [markdown]
# ## 2.1: stimus types:

# %%
balloon_type_counts = task['balloonType'].value_counts()
plt.figure(figsize=(8,6))
balloon_type_counts.plot(kind='bar')
plt.title('Count of Different Balloon Types')
plt.xlabel('Balloon Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.2: mean RT:

# %%
reaction_time_mean = task['reactionTime (ms)'].mean()
print("Mean reaction time (ms):", reaction_time_mean)
# Out:
# Mean reaction time (ms): 1076.3084000012875

# %% [markdown]
# ### 2.2.1: stim based mean RT:

# %%
reaction_time_by_balloon = task.groupby('balloonType')['reactionTime (ms)'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,6))
reaction_time_by_balloon.plot(kind='bar')
plt.title('Mean Reaction Time by Balloon Type')
plt.xlabel('Balloon Type')
plt.ylabel('Mean Reaction Time (ms)')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 2.3: mean IT:

# %%
reaction_time_mean = task['inflationTime (ms)'].mean()
print("Mean inflation time (ms):", reaction_time_mean)
# Out:
# Mean inflation time (ms): 2550.8499999976157

# %% [markdown]
# ### 2.3.1: stim based mean IT:

# %%
reaction_time_by_balloon = task.groupby('balloonType')['inflationTime (ms)'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,6))
reaction_time_by_balloon.plot(kind='bar')
plt.title('Mean Inflation Time by Balloon Type')
plt.xlabel('Balloon Type')
plt.ylabel('Mean Inflation Time (ms)')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 2.4: outcome status:
# gray and special stimulus were removed!

# %%
filtered_task = task[~task['balloonType'].str.contains('gray|special', case=False)]

outcome_percentage = filtered_task['outcome'].value_counts(normalize=True) * 100
plt.figure(figsize=(8,6))
outcome_percentage.plot(kind='bar')
plt.title('Outcome Percentage Distribution')
plt.xlabel('Outcome')
plt.ylabel('Percentage(%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4.1: color based outcome:

# %%
outcome_by_balloon = filtered_task.groupby('balloonType')['outcome'].value_counts(normalize=True).unstack() * 100
outcome_by_balloon.plot(kind='bar', figsize=(10, 6))
plt.title('Outcome Percentage by Balloon Type')
plt.xlabel('Balloon Type')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. questionnaire data

# %%
file_path = '1_nill/questionnaire_responses_10_09_2024_19_30_27.csv'
questionnaire = pd.read_csv(file_path)
questionnaire
# Out:
#        question                answer
# 0    Question_1  Almost Always/Always
# 1    Question_2          Rarely/Never
# 2    Question_3          Rarely/Never
# 3    Question_4          Rarely/Never
# 4    Question_5          Occasionally
# 5    Question_6          Occasionally
# 6    Question_7  Almost Always/Always
# 7    Question_8                 Often
# 8    Question_9          Occasionally
# 9   Question_10  Almost Always/Always
# 10  Question_11          Occasionally
# 11  Question_12  Almost Always/Always
# 12  Question_13  Almost Always/Always
# 13  Question_14          Rarely/Never
# 14  Question_15  Almost Always/Always
# 15  Question_16          Rarely/Never
# 16  Question_17          Occasionally
# 17  Question_18          Rarely/Never
# 18  Question_19          Occasionally
# 19  Question_20          Occasionally
# 20  Question_21          Rarely/Never
# 21  Question_22          Rarely/Never
# 22  Question_23  Almost Always/Always
# 23  Question_24          Occasionally
# ...
